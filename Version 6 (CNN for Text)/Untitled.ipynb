# %%
import pandas as pd

# %%
train = pd.read_excel("Dataset1/nepal/temp.xlsx")

# %%
# train['text'][0]
# train['label'][0]
dataColumn = 'text'
labelColumn = 'label'

# %%
def Preprocess(x):
#     if '@' in x:
#         return x + '999'
    return x == '@jonsnowC3'

# %%
df1 = train.text.str.split(expand=True).apply(Preprocess).fillna('')

# %%
for index, row in train.iterrows():
    print(row[dataColumn])
    break
# Out:
# RT @AnupKaphle: #Nepal's prime minister addressed the country for 1st time since earthquake on Saturday. No concrete plans, lots of referenâ€°Ã›_

# %%
df1
# Out:
#                  0               1                        2          3   \
# 0                RT    @AnupKaphle:                 #Nepal's      prime
# 1        @jonsnowC4              So                     have        we;
# 2              Lend               a                  helping       hand
# 3      @shilpaanand         they've                  managed         to
# 4            Israel         Sending                      Aid      Teams
# 5                RT   @AUThackeray:                      All       Shiv
# 6           British    archeologist              'terrified'      after
# 7                RT      @nrarmour:                     More      kudos
# 8                RT     @namgayzam:                  #Bhutan         's
# 9                RT   @OCHAAsiaPac:             #Nepalquake:         An
# 10            Nepal     earthquake:              Devastation         in
# 11               RT      @MEAIndia:          #IndiaWithNepal       More
# ...
