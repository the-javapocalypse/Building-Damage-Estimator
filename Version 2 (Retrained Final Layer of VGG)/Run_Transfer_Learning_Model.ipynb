# %% [markdown]
# # Running Model Trained Through Transfer Learning (VGG 16)
#
# ---
#
#
# ## Description
# This script will run the model trained by Transfer_Learning_Training.ipynb
# There are two functions.
# * LoadModel() : Loads model
# * predict() : Takes model and directory path for images to be predicted as arguments and classify the image. Last three lines of the method can be uncommented to move irrelevant or relevant images to different folders
#
#
# ### Usage
# Can be used as a filter damaged buildings and undamaged buildings and move them in different directories.

# %%
import os
from os import listdir
from os.path import isfile, join
from shutil import copyfile
from keras import applications
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras import optimizers
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense
import numpy as np
from keras import Model

# %%
img_width, img_height = 150, 150

# %%
def LoadModel(modelPath):
    top_model_weights_path = modelPath #Additional layer weights
    # build the VGG16 network
    model = applications.VGG16(weights='imagenet', include_top=False, input_shape=(150, 150, 3))
    print('vgg16 Model loaded.')
    #Additional layers for vgg16
    top_model = Sequential()
    top_model.add(Flatten(input_shape=model.output_shape[1:]))
    top_model.add(Dense(256, activation='relu'))
    top_model.add(Dropout(0.5))
    top_model.add(Dense(1, activation='sigmoid'))
    top_model.load_weights(top_model_weights_path) #Weights for new layers loaded
    #join new layers to ouyput of vgg16
    model = Model(input= model.input, output= top_model(model.output))
    model.compile(loss='binary_crossentropy',
                  optimizer=optimizers.SGD(lr=1e-4, momentum=0.9),
                  metrics=['accuracy'])
#     model.load_weights('fine_tuned_weights.h5') #load the weights for fine tuned
    return model

# %%
def predict(basedir, model):
    onlyfiles = [f for f in listdir(basedir) if
                 isfile(join(basedir, f))]
    i=0
    for img_name in onlyfiles:
        img_path=basedir+"/"+img_name
        img = load_img(img_path, False, target_size=(img_width, img_height))
        x = img_to_array(img)
        x = np.expand_dims(x, axis=0)
        preds = model.predict(x)
        pred_folder = str(int(preds[0][0]))
        if preds[0][0] == 0 or preds[0][0] == 1:
            print(str(i) + " prediction " + pred_folder + " probability " + str(preds[0][0]))
            i += 1
            try:
                os.stat(pred_folder)
            except:
                os.mkdir(pred_folder )
#             copyfile(img_path,pred_folder + '/' +img_name)
#         else:
#             copyfile(img_path, "unknown" + '/' + img_name)

# %%
model = LoadModel('bottleneck_50_epochs.h5')
# Out:
# vgg16 Model loaded.
# C:\Users\Javapocalypse\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("se...)`

# %%
basedir = "dataset/predictions"
predict(basedir, model)
# Out:
# 0 prediction 0 probability 0.0
# 1 prediction 0 probability 0.0
# 2 prediction 0 probability 0.0
# 3 prediction 0 probability 0.0
# 4 prediction 0 probability 0.0
# 5 prediction 1 probability 1.0
# 6 prediction 1 probability 1.0
# 7 prediction 1 probability 1.0
# 8 prediction 0 probability 0.0
# 9 prediction 1 probability 1.0
# 10 prediction 1 probability 1.0
# 11 prediction 1 probability 1.0
# 12 prediction 0 probability 0.0
# 13 prediction 1 probability 1.0
# 14 prediction 1 probability 1.0
# 15 prediction 0 probability 0.0
# 16 prediction 1 probability 1.0
# 17 prediction 1 probability 1.0
# 18 prediction 1 probability 1.0
# 19 prediction 0 probability 0.0
# 20 prediction 0 probability 0.0
# 21 prediction 0 probability 0.0
# 22 prediction 0 probability 0.0
# 23 prediction 0 probability 0.0
# 24 prediction 0 probability 0.0
# 25 prediction 0 probability 0.0
# 26 prediction 0 probability 0.0
# 27 prediction 1 probability 1.0
# 28 prediction 0 probability 0.0
# 29 prediction 1 probability 1.0
# 30 prediction 0 probability 0.0
# 31 prediction 0 probability 0.0
# 32 prediction 0 probability 0.0
# 33 prediction 1 probability 1.0
# 34 prediction 1 probability 1.0
# 35 prediction 1 probability 1.0
# 36 prediction 1 probability 1.0
# 37 prediction 0 probability 0.0
# 38 prediction 1 probability 1.0
# 39 prediction 0 probability 0.0
# 40 prediction 0 probability 0.0
# 41 prediction 1 probability 1.0
# 42 prediction 0 probability 0.0
# 43 prediction 0 probability 0.0
# 44 prediction 1 probability 1.0
# 45 prediction 0 probability 0.0
# 46 prediction 1 probability 1.0
# 47 prediction 0 probability 0.0
# 48 prediction 1 probability 1.0
# 49 prediction 0 probability 0.0
# 50 prediction 1 probability 1.0
# 51 prediction 1 probability 1.0
# 52 prediction 0 probability 0.0
# 53 prediction 1 probability 1.0
# 54 prediction 1 probability 1.0
# 55 prediction 0 probability 0.0
# 56 prediction 0 probability 0.0
# 57 prediction 0 probability 0.0
# 58 prediction 1 probability 1.0
# 59 prediction 0 probability 0.0
# 60 prediction 0 probability 0.0
# 61 prediction 1 probability 1.0
# 62 prediction 1 probability 1.0
# 63 prediction 0 probability 0.0
# 64 prediction 1 probability 1.0
# 65 prediction 0 probability 0.0
# 66 prediction 1 probability 1.0
# 67 prediction 0 probability 0.0
# 68 prediction 1 probability 1.0
# 69 prediction 1 probability 1.0
# 70 prediction 1 probability 1.0
# 71 prediction 1 probability 1.0
# 72 prediction 1 probability 1.0
# 73 prediction 1 probability 1.0
# 74 prediction 1 probability 1.0
# 75 prediction 1 probability 1.0
# 76 prediction 1 probability 1.0
# 77 prediction 0 probability 0.0
# 78 prediction 1 probability 1.0
# 79 prediction 1 probability 1.0
# 80 prediction 0 probability 0.0
# 81 prediction 0 probability 0.0
# 82 prediction 1 probability 1.0
# 83 prediction 0 probability 0.0
# 84 prediction 1 probability 1.0
# 85 prediction 0 probability 0.0
# 86 prediction 1 probability 1.0
# 87 prediction 0 probability 0.0
# 88 prediction 1 probability 1.0
# 89 prediction 0 probability 0.0
# 90 prediction 0 probability 0.0
# 91 prediction 1 probability 1.0
# 92 prediction 1 probability 1.0
# 93 prediction 0 probability 0.0
# 94 prediction 1 probability 1.0
# 95 prediction 1 probability 1.0
# 96 prediction 1 probability 1.0
# 97 prediction 1 probability 1.0
# 98 prediction 1 probability 1.0
# 99 prediction 1 probability 1.0
# 100 prediction 1 probability 1.0
# 101 prediction 0 probability 0.0
# 102 prediction 1 probability 1.0
# 103 prediction 0 probability 0.0
# 104 prediction 0 probability 0.0
# 105 prediction 1 probability 1.0
# 106 prediction 1 probability 1.0
# 107 prediction 1 probability 1.0
# 108 prediction 0 probability 0.0
# 109 prediction 1 probability 1.0
# 110 prediction 1 probability 1.0
# 111 prediction 1 probability 1.0
# 112 prediction 0 probability 0.0
# 113 prediction 0 probability 0.0
# 114 prediction 0 probability 0.0
# 115 prediction 0 probability 0.0
# 116 prediction 1 probability 1.0
# 117 prediction 1 probability 1.0
# 118 prediction 1 probability 1.0
# 119 prediction 1 probability 1.0
# 120 prediction 0 probability 0.0
# 121 prediction 1 probability 1.0
# 122 prediction 1 probability 1.0
# 123 prediction 1 probability 1.0
# 124 prediction 0 probability 0.0
# 125 prediction 1 probability 1.0
# 126 prediction 0 probability 0.0
# 127 prediction 0 probability 0.0
# 128 prediction 0 probability 0.0
# 129 prediction 1 probability 1.0
# 130 prediction 0 probability 0.0
# 131 prediction 1 probability 1.0
# 132 prediction 1 probability 1.0
# 133 prediction 1 probability 1.0
# 134 prediction 0 probability 0.0
# 135 prediction 1 probability 1.0
# 136 prediction 1 probability 1.0
# 137 prediction 1 probability 1.0
# 138 prediction 1 probability 1.0
# 139 prediction 1 probability 1.0
# 140 prediction 1 probability 1.0
# 141 prediction 1 probability 1.0
# 142 prediction 1 probability 1.0
# 143 prediction 1 probability 1.0
# 144 prediction 1 probability 1.0
# 145 prediction 1 probability 1.0
# 146 prediction 1 probability 1.0
# 147 prediction 1 probability 1.0
# 148 prediction 1 probability 1.0
# 149 prediction 1 probability 1.0
# 150 prediction 1 probability 1.0
# 151 prediction 1 probability 1.0
# 152 prediction 1 probability 1.0
# 153 prediction 1 probability 1.0
# 154 prediction 1 probability 1.0
# 155 prediction 0 probability 0.0
# 156 prediction 0 probability 0.0
# 157 prediction 0 probability 0.0
# 158 prediction 0 probability 0.0
# 159 prediction 0 probability 0.0
# 160 prediction 1 probability 1.0
# 161 prediction 1 probability 1.0
# 162 prediction 1 probability 1.0
# 163 prediction 0 probability 0.0
# 164 prediction 0 probability 0.0
# 165 prediction 1 probability 1.0
# 166 prediction 0 probability 0.0
# 167 prediction 0 probability 0.0
# 168 prediction 0 probability 0.0
# 169 prediction 1 probability 1.0
# 170 prediction 0 probability 0.0
# 171 prediction 1 probability 1.0
# 172 prediction 0 probability 0.0
# 173 prediction 1 probability 1.0
# 174 prediction 1 probability 1.0
# 175 prediction 1 probability 1.0
# 176 prediction 1 probability 1.0
# 177 prediction 1 probability 1.0
# 178 prediction 0 probability 0.0
# 179 prediction 1 probability 1.0
# 180 prediction 1 probability 1.0
# 181 prediction 1 probability 1.0
# 182 prediction 1 probability 1.0
# 183 prediction 1 probability 1.0
# 184 prediction 0 probability 0.0
# 185 prediction 0 probability 0.0
# 186 prediction 0 probability 0.0
# 187 prediction 0 probability 0.0
# 188 prediction 1 probability 1.0
# 189 prediction 0 probability 0.0
# 190 prediction 0 probability 0.0
# 191 prediction 0 probability 0.0
# 192 prediction 0 probability 0.0
# 193 prediction 0 probability 0.0
# 194 prediction 1 probability 1.0
# 195 prediction 1 probability 1.0
# 196 prediction 0 probability 0.0
# 197 prediction 1 probability 1.0
# 198 prediction 1 probability 1.0
# 199 prediction 1 probability 1.0
# 200 prediction 0 probability 0.0
# 201 prediction 0 probability 0.0
# 202 prediction 1 probability 1.0
# 203 prediction 1 probability 1.0
# 204 prediction 1 probability 1.0
# 205 prediction 0 probability 0.0
# 206 prediction 0 probability 0.0
# 207 prediction 1 probability 1.0
# 208 prediction 0 probability 0.0
# 209 prediction 0 probability 0.0
# 210 prediction 0 probability 0.0
# 211 prediction 1 probability 1.0
# 212 prediction 1 probability 1.0
# 213 prediction 1 probability 1.0
# 214 prediction 0 probability 0.0
# 215 prediction 0 probability 0.0
# 216 prediction 1 probability 1.0
# 217 prediction 1 probability 1.0
# 218 prediction 1 probability 1.0
# 219 prediction 0 probability 0.0
# 220 prediction 0 probability 0.0
# 221 prediction 0 probability 0.0
# 222 prediction 1 probability 1.0
# 223 prediction 1 probability 1.0
# 224 prediction 1 probability 1.0
# 225 prediction 0 probability 0.0
# 226 prediction 0 probability 0.0
# 227 prediction 1 probability 1.0
# 228 prediction 1 probability 1.0
# 229 prediction 0 probability 0.0
# 230 prediction 1 probability 1.0
# 231 prediction 0 probability 0.0
# 232 prediction 0 probability 0.0
# 233 prediction 1 probability 1.0
# 234 prediction 0 probability 0.0
# 235 prediction 1 probability 1.0
# 236 prediction 0 probability 0.0
# 237 prediction 0 probability 0.0
# 238 prediction 1 probability 1.0
# 239 prediction 0 probability 0.0
# 240 prediction 0 probability 0.0
# 241 prediction 0 probability 0.0
# 242 prediction 1 probability 1.0
# 243 prediction 1 probability 1.0
# 244 prediction 0 probability 0.0
# 245 prediction 0 probability 0.0
# 246 prediction 0 probability 0.0
# 247 prediction 0 probability 0.0
# 248 prediction 1 probability 1.0
# 249 prediction 1 probability 1.0
# 250 prediction 1 probability 1.0
# 251 prediction 1 probability 1.0
# 252 prediction 0 probability 0.0
# 253 prediction 1 probability 1.0
# 254 prediction 1 probability 1.0
# 255 prediction 1 probability 1.0
# 256 prediction 1 probability 1.0
# 257 prediction 1 probability 1.0
# 258 prediction 1 probability 1.0
# 259 prediction 0 probability 0.0
# 260 prediction 1 probability 1.0
# 261 prediction 0 probability 0.0
# 262 prediction 0 probability 0.0
# 263 prediction 0 probability 0.0
# 264 prediction 1 probability 1.0
# 265 prediction 0 probability 0.0
# 266 prediction 1 probability 1.0
# 267 prediction 1 probability 1.0
# 268 prediction 1 probability 1.0
# 269 prediction 1 probability 1.0
# 270 prediction 1 probability 1.0
# 271 prediction 0 probability 0.0
# 272 prediction 1 probability 1.0
# 273 prediction 1 probability 1.0
# 274 prediction 1 probability 1.0
# 275 prediction 0 probability 0.0
# 276 prediction 0 probability 0.0
# 277 prediction 1 probability 1.0
# 278 prediction 1 probability 1.0
# 279 prediction 0 probability 0.0
# 280 prediction 1 probability 1.0
# 281 prediction 1 probability 1.0
# 282 prediction 1 probability 1.0
# 283 prediction 1 probability 1.0
# 284 prediction 0 probability 0.0
# 285 prediction 1 probability 1.0
# 286 prediction 1 probability 1.0
# 287 prediction 0 probability 0.0
# 288 prediction 0 probability 0.0
# 289 prediction 0 probability 0.0
# 290 prediction 0 probability 0.0
# 291 prediction 0 probability 0.0
# 292 prediction 0 probability 0.0
# 293 prediction 0 probability 0.0
# 294 prediction 0 probability 0.0
# 295 prediction 0 probability 0.0
